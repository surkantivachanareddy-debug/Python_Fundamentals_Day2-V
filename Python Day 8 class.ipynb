# %%
Installation  and setup of python environment

# %%
software needed

1. www.anaconda.com (Jupyter.notebook)
2.www.github.com (code versioning system)

# %%
www.anaconda .com
steps to be followed:-

1. open www.anaconda .com
2. choose the download option available on the screen
3. go to download and run the .exe file ....> next....>next....>next....> anaconda will be installed on your system
4. it will be creating a shortcut on your desktop called as "Anaconda navigation"
5. open the anaconda navigator ...> choose "jupyernotebook"....>click on launch
6. it will be opening up in your browser.

# %%
www.github.com
steps to be followed:-

1. open www.github.com
2. craete your account by doing signup
3. login to github
4. create a repository (python Fundamental)
5. upload your code files to the repository
6. commit the code.
