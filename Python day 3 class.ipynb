# %%
Introduction to f string

# %%
# general syntax of f string

# %%
f"custom message, {place holder1},{place holder2},(place holder3},......{place holdern}

# %%
firstname ="kiran"
lastname ="reddy"

# %%
# Req-- I want to get the fullname...?

# %%
fullname = f"{firstname} {lastname}"

print(fullname)
# Out:
# kiran reddy

# %%
print(fullname.title())
# Out:
# Kiran Reddy

# %%
message = f"keepup the good work, {fullname.title()}"

print(message)

# %%
Adding whitespaces to the strings

# %%
print("favourite_Prog_lang : Pythonc++JavaCSwiftJavaScript")
# Out:
# favourite_Prog_lang : Pythonc++JavaCSwiftJavaScript

# %%
print("favourite_prog_lang : \nPython\nc++\nJava\nC\nSwift\nJavaScript")  #\n---newline delimiter
# Out:
# favourite_prog_lang :
# Python
# c++
# Java
# C
# Swift
# JavaScript

# %%
print("favourite_Prog_lang :\n\tPython\n\tc++\n\tJava\n\tC\n\tSwift\n\tJavaScript") #\t tab delimiter
# Out:
# favourite_Prog_lang :
# 	Python
# 	c++
# 	Java
# 	C
# 	Swift
# 	JavaScript

# %%
Removing whitespaces from the string

# %%
name = " Python"  

print(name)
# Out:
#  Python

# %%
name2 = "Python "

print(name2)
# Out:
# Python

# %%
How to fix this white spaces

# %%
name.lstrip()   #Left gap (gaps are nothinh but whitespaces)
# Out:
# 'Python'

# %%
name.rstrip()   #right gap
# Out:
# ' Python'

# %%
name3 = " Python "

print(name3)
# Out:
#  Python

# %%
name3.strip()   #both sides gap
# Out:
# 'Python'

# %%
# zen of python

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
