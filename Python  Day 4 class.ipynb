# %%
Introduction  to numbers

# %%
num = 1 

num = 4

# %%
type(num)
# Out:
# int

# %%
x = 0.1

print(x)
# Out:
# 0.1

# %%
type(x)   #decimal values in python
# Out:
# float

# %%
Introduction to list datatype

# %%
Definition - A list is a Collection of items declared in a particular order.

# %%
Classification -- it is classified as mutable datatype

# %%
how do you define the list ---->[] Square brackets

# %%
students = ['vicky','abdul','shree','anwar','murali']   # 0,1,2,3,4,5

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murali']

# %%
Introduction to Indexing

# %%
Accessing elements in a sequence using their position number.

# %%
How to access the elements in the list?

# %%
req-- I want to access abdul name in the output

# %%
print(students[1])
# Out:
# abdul

# %%
print(students[1].title())
# Out:
# Abdul

# %%
1. How to add new element to the list

# %%
2.How to modify the element to the list

# %%
3.How to delete the element in the list

# %%
print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murali']

# %%
# add name varun to the list

# %%
students.append('varun')

print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murali', 'varun']

# %%
# add name Praneeth

# %%
students.append('praneeth')

print(students)
# Out:
# ['vicky', 'abdul', 'shree', 'anwar', 'murali', 'varun', 'praneeth']

# %%
Append() -- will add the element to the last of the list.

# %%
Req-- i want to add name divya to 2nd index

# %%
students.insert(2,'divya')

print(students)
# Out:
# ['vicky', 'abdul', 'divya', 'shree', 'anwar', 'murali', 'varun', 'praneeth']

# %%
Note: what is the difference between Append and Insert method in the list datatype

# %%
# modify the element

# %%
print (students)
# Out:
# ['vicky', 'abdul', 'divya', 'shree', 'anwar', 'murali', 'varun', 'praneeth']

# %%
Req ---I want to modify divya name to dinesh

# %%
students[2] = "dinesh"

print(students)
# Out:
# ['vicky', 'abdul', 'dinesh', 'shree', 'anwar', 'murali', 'varun', 'praneeth']

# %%
Indexing plays a important and very critical role in terms of a programming

# %%
# delete the element

# %%
Req-- I want to delete vicky name from the list

# %%
for deleting there are two different appraches

# %%
1 temporary deleting -- it wll be storing a carbon copy of the deleted item to the variables assigned

# %%
2 permanent deleting

# %%
for temporary deleting ----method pop()

# %%
By default pop will be deleting the last element in the list

# %%
x = students.pop()

print(students)
# Out:
# ['vicky', 'abdul', 'dinesh', 'shree', 'anwar', 'murali']

# %%
print(x)
# Out:
# varun

# %%
a = students.pop(0)

print(students)
# Out:
# ['abdul', 'dinesh', 'shree', 'anwar', 'murali']

# %%
print(a)
# Out:
# vicky

# %% [raw]
# permanent deleting----

# %%
Req-- I want to delete dinesh

# %%
del students[1]

print(students)
# Out:
# ['abdul', 'shree', 'anwar', 'murali']

# %%
Note:- what is the difference between pop() and del() method in a list datatype and can you please explain?
