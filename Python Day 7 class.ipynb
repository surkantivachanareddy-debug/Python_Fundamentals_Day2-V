# %%
Introduction to Dictionary

# %%
Definition : A dictionary is a combination of key value pairs
classification - it is classified as a mutable datatype

# %%
How to define/declare the dictionary {}     #curly brackets or flower brackets

# %%
# I want to craete a alien game....

# %%
alien = {'colour': 'green', 'point': 5}
print(alien)
# Out:
# {'colour': 'green', 'point': 5}

# %%
type(alien)
# Out:
# dict

# %%
# dictionary in the shortform written as dict

# %%
# how to add new key value pairs in the dictionary

# %%
# I want to add start position of the alien
# start position = level1

# %%
alien['start position'] = 'level1'

print(alien)
# Out:
# {'colour': 'green', 'point': 5, 'start position': 'level1'}

# %%
# how to access the key value pairs we will be seeing and understanding

# %%
Note: In the dictionary key's will be acting as indexing points
where as n the lst and tuple index is used to access the elements

# %%
alien['colour']
# Out:
# 'green'

# %%
alien['start position']
# Out:
# 'level1'

# %%
alien['point']
# Out:
# 5

# %%
# give the key and get the value

# %%
# create a new user account in the Instagram

# %%
user_account = {'username':'codetraining01','username':'code','dob':'01-01-2020','password':'54321'}

print(user_account)
# Out:
# {'username': 'code', 'dob': '01-01-2020', 'password': '54321'}

# %%
# i want to delete a key value pair.....

# %%
# I want to delete username

# %%
del user_account['username']
print(user_account)
# Out:
# {'dob': '01-01-2020', 'password': '54321'}

# %%
print(alien)
# Out:
# {'colour': 'green', 'point': 5, 'start position': 'level1'}

# %%
alien['level1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 alien['level1']
#
# KeyError: 'level1'

# %%
# only key is given not the value.

# %%
# Implementation of a for loop on top of a dictionary:

# %%
#general syntax

# %%
for tempvar1,tempvar2 in mainvar.items():
    print(tempvar1)
    print(tempvar2)

# %%
print(alien)
# Out:
# {'colour': 'green', 'point': 5, 'start position': 'level1'}

# %%
for k,v in alien.items():
    print(k)
    print(v)
# Out:
# colour
# green
# point
# 5
# start position
# level1

# %%
for k,v in alien.items():
    print{f'key : (k)'
    print{f'value: (v)'\n}
# Out:
#   Cell In[23], line 2
#     print{f'key : (k)'
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
for k,v in alien.items():
    print{f'key: (k)'}
    print{f'value: (v)'\n}
# Out:
#   Cell In[24], line 2
#     print{f'key: (k)'}
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
for k, v in alien.items():
    print(f"key: {k}")
    print(f"value: {v}\n")
# Out:
# key: colour
# value: green
#
# key: point
# value: 5
#
# key: start position
# value: level1

# %%
for k, v in alien.items():
    print(f"key: {k}")
    print(f"value: {v}")
# Out:
# key: colour
# value: green
# key: point
# value: 5
# key: start position
# value: level1
