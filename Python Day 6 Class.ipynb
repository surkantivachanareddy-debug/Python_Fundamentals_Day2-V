# %%
Introduction to list

# %%
List is nothing but a collection of items declared in a particular order.

Classification - it is classified as mutable datatype.

# %%
How to define a list - by using a [] square brackets

# %%
Introduction to Tuple

# %%
An immutable list is called as a tuple datatype 

Classification - it is classified as immutable datatype

# %%
How to define a tuple - by using a ()

# %%
dimension = (20,60)

print (dimension)
# Out:
# (20, 60)

# %%
type(dimension)
# Out:
# tuple

# %%
when ever we don't want our data  to get modified easily
when ever we wanted our date remain fixed or at a constant level, without any changes that time we will prefer the tuple datatype
example dimensions

# %%
dimension[0] = 25
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dimension[0] = 25
#
# TypeError: 'tuple' object does not support item assignment

# %%
Introduction to looping statement

# %%
Introduction to for loop:

# %%
# genereal syntax

# %%
for tempvar in mainvar
    print(tempvar)

# %%
students = ["vicky","sudhakar","navya","neha","sai","devid"]

print(students)
# Out:
# ['vicky', 'sudhakar', 'navya', 'neha', 'sai', 'devid']

# %%
print(students)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(students)
#
# NameError: name 'students' is not defined

# %%
message = f"Keep up the good work,{students(0).title()}

print(message)
# Out:
#   Cell In[9], line 1
#     message = f"Keep up the good work,{students(0).title()}
#               ^
# SyntaxError: unterminated f-string literal (detected at line 1)

# %%
message = f"Keep up the good work,{students[0].title()}"

print(message)
# Out:
# Keep up the good work,Vicky

# %%
message = f"Keep up the good work,{students[1].title()}"

print(message)
# Out:
# Keep up the good work,Sudhakar

# %%
for sending messages to all the people at once
implementation of for loop

# %%
for x in students:
    print(f"Keep up the good work, {x.title()}")
# Out:
# Keep up the good work, Vicky
# Keep up the good work, Sudhakar
# Keep up the good work, Navya
# Keep up the good work, Neha
# Keep up the good work, Sai
# Keep up the good work, Devid

# %%
for x in students:
    print(f"Keep up the good work, {x.title()}")
    print(f"I will be looking forword to receive your githib url for the review {x.title()}")
# Out:
# Keep up the good work, Vicky
# I will be looking forword to receive your githib url for the review Vicky
# Keep up the good work, Sudhakar
# I will be looking forword to receive your githib url for the review Sudhakar
# Keep up the good work, Navya
# I will be looking forword to receive your githib url for the review Navya
# Keep up the good work, Neha
# I will be looking forword to receive your githib url for the review Neha
# Keep up the good work, Sai
# I will be looking forword to receive your githib url for the review Sai
# Keep up the good work, Devid
# I will be looking forword to receive your githib url for the review Devid

# %%
# enhancement of the code....

# %%
for x in students:
    print(f"Keep up the good work, {x.title()}")
    print(f"I will be looking forword to receive your githib url for the review {x.title()}\n")
# Out:
# Keep up the good work, Vicky
# I will be looking forword to receive your githib url for the review Vicky
#
# Keep up the good work, Sudhakar
# I will be looking forword to receive your githib url for the review Sudhakar
#
# Keep up the good work, Navya
# I will be looking forword to receive your githib url for the review Navya
#
# Keep up the good work, Neha
# I will be looking forword to receive your githib url for the review Neha
#
# Keep up the good work, Sai
# I will be looking forword to receive your githib url for the review Sai
#
# Keep up the good work, Devid
# I will be looking forword to receive your githib url for the review Devid

# %%
print(students)
# Out:
# ['vicky', 'sudhakar', 'navya', 'neha', 'sai', 'devid']

# %%
#The gap between colon and print is called Indentation

# %%
for x in students:
print(f"Keep up the good work, {x.title()}")
# Out:
#   Cell In[17], line 2
#     print(f"Keep up the good work, {x.title()}")
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
for x in students:
    print(f"Keep up the good work, {x.title()}")
    print(f"I will be looking forword to receive your githib url for the review {x.title()}\n")
print("Thank you all for joining in the python session")
# Out:
# Keep up the good work, Vicky
# I will be looking forword to receive your githib url for the review Vicky
#
# Keep up the good work, Sudhakar
# I will be looking forword to receive your githib url for the review Sudhakar
#
# Keep up the good work, Navya
# I will be looking forword to receive your githib url for the review Navya
#
# Keep up the good work, Neha
# I will be looking forword to receive your githib url for the review Neha
#
# Keep up the good work, Sai
# I will be looking forword to receive your githib url for the review Sai
#
# Keep up the good work, Devid
# I will be looking forword to receive your githib url for the review Devid
#
# Thank you all for joining in the python session
