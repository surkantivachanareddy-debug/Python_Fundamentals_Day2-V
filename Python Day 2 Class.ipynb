# %%
Introduction to Python Programming

# %%
Understanding the variables in python

# %%
a = 2
b = 3

# %%
c = a + b

# %%
print(c)
# Out:
# 5

# %%
Variables are nothing but the position holding that we are assigning

# %%
Rules for declaring the variables in python

# %%
3 rules to be learn

# %%
Rule 1 - No namespace while declaring the variables

# %%
first name = "Vachana"

print(first name)
# Out:
#   Cell In[16], line 1
#     first name = "Vachana"
#           ^
# SyntaxError: invalid syntax

# %%
firstname = "Vachana"

print(firstname)
# Out:
# Vachana

# %%
first_name = "vachana"

print(first_name)
# Out:
# vachana

# %%
Rule 2 - A variable name should not start with a number

# %%
1name = "anand"

print(1name)
# Out:
#   Cell In[19], line 1
#     1name = "anand"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "anand"

print(name1)
# Out:
# anand

# %%
Rule 3 = A variable name should not contain any space characters.

# %%
# $ % & *  All these are special charaters avoid it

# %%
name@ = "Vachana"

# %%
print(name@)
# Out:
#   Cell In[21], line 1
#     print(name@)
#                ^
# SyntaxError: invalid syntax

# %%
Introduction to data types in python

# %%
1 String-----str

# %%
2 numbers ----- interger --int
          ----- float --  (decimales)

# %%
3 list

# %%
4 tuples

# %%
5 Dictionaries --dict

# %%
Note:- Python programming is a case senstive programming language.

# %%
Classification of datatypes

# %%
Broadly datatypes are classify into two categories

# %%
1 mutable datatype -----> which we able to edit /alter (flexible in nature)

# %%
2 immutable datatype ----> which we will not able to edit/alter (fixed in nature)

# %%
Introduction to string datatype

# %%
Definition -- A string is nothing but a series of characters declared in quotes.

# %%
Classification -- It is classified as an immutable datatype

# %%
How do you define the string datatype?

# %%
1 Single quote

# %%
2 double quote

# %%
name = 'akash'  # single quote

print(name)
# Out:
# akash

# %%
name1 = "Hajera"   # double quote

print(name1)
# Out:
# Hajera

# %%
Introduction to string methods

# %%
Methods are buildin function

# %%
type(name)
# Out:
# str

# %%
type(name1)
# Out:
# str

# %%
when ever executing assigning the number

# %%
# Shift+Enter---To run the program

# %%
# is used for commenting th code

# %%
fullname = "kiran reddy"

print(fullname)
# Out:
# kiran reddy

# %%
print(fullname.title())  # First letter change to capital
# Out:
# Kiran Reddy

# %%
# i want to get the entire name in the capital letters

# %%
print(fullname.upper())
# Out:
# KIRAN REDDY

# %%
# i want to get the name in the small case letters

# %%
print(fullname.lower())
# Out:
# kiran reddy
